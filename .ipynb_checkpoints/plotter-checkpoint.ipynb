# %%
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
result = {}
for n in [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048]:
    result[n] = {}
    for degree in [2, 3, 4, 5]:
        result[n][degree] = {}
        my_range = np.linspace(0.4 *degree*np.log2(n), 6 * degree*np.log2(n), 50)
        m_list = [int(a) for a in my_range]
        for m in m_list:
            result[n][degree][m] = []
            for try_no in range(20):
                try:
                    f =open(f"results/n={n}_m={m}_d={degree}_{try_no}.json") as f:
                    data = json.loads(f.read())
                    result[n][degree][m].append(data)
                except:
                    print(f"Couldn't find results/n={n}_m={m}_d={degree}_{try_no}.json")
                    print(f"Assume job failed")
                    data = {'status': False, 'time':60*60*4, 'n': n, 'm': m, 'd': degree}
                    result[n][degree][m].append(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/8y/m9vhchj936vgs1174cc10zbw0000gn/T/ipykernel_83663/4023718992.py in <module>
#       9             result[n][degree][m] = []
#      10             for try_no in range(20):
# ---> 11                 with open(f"results/n={n}_m={m}_d={degree}_{try_no}.json") as f:
#      12                     try:
#      13                         data = json.loads(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/n=1024_m=100_d=5_17.json'

# %%
# failure rates
for n in result:
    for degree in result[n]:
        no_measurements , p_failure, time  = [], [], []
        print(degree)
        for m in result[n][degree]:
            p = sum([1 for j in range(20) if result[n][degree][m][j]["status"]==True])/20
            no_measurements.append(m)
            p_failure.append(p)
            time.append(np.median([result[n][degree][m][j]["time"] for j in range(20)]))
            
        # print(p_failure, time)
        fig, (ax1, ax2) = plt.subplots(2, 1)
        ax1.set_ylabel("probability of success", color="blue")
        ax1.set_xlabel("number of measurments")
        my_len = len(no_measurements)
        ax1.plot(no_measurements, p_failure, label="random")
        ax1.plot( [2*degree*np.log2(n)]*my_len, np.linspace(0,1,my_len), label="reed-solomon")
        ax1.plot( [lower_bound(n, degree)]*my_len, np.linspace(0,1,my_len), label = "lower-bound")
        ax1.xaxis.grid()
        ax1.yaxis.grid()
        ax1.set_title(f"n={n} degree={degree}")
        
        ax2.set_ylabel("median time (s)", color="blue")
        ax2.set_xlabel("number of measurments")
        ax2.plot(no_measurements, time)
        ax2.xaxis.grid()
        ax2.yaxis.grid()
        
        
        
        plt.show()
# Out:
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/8y/m9vhchj936vgs1174cc10zbw0000gn/T/ipykernel_83663/1839021651.py in <module>
#       5         print(degree)
#       6         for m in result[n][degree]:
# ----> 7             p = sum([1 for j in range(20) if result[n][degree][m][j]["status"]==True])/20
#       8             no_measurements.append(m)
#       9             p_failure.append(p)
#
# /var/folders/8y/m9vhchj936vgs1174cc10zbw0000gn/T/ipykernel_83663/1839021651.py in <listcomp>(.0)
#       5         print(degree)
#       6         for m in result[n][degree]:
# ----> 7             p = sum([1 for j in range(20) if result[n][degree][m][j]["status"]==True])/20
#       8             no_measurements.append(m)
#       9             p_failure.append(p)
#
# IndexError: list index out of range

# %%
from math import ceil 
result_binning = {}
for n in [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]:
    result_binning[n] = {}
    for degree in [2,3,4,5]:
        result_binning[n][degree] = {}
        no_bins_range = np.linspace(0.1 * degree**2,  degree**2, 10)
        no_bins_range = [ceil(a) for a in no_bins_range]
        for no_bins in no_bins_range:
            for no_iterations in [1,2,3,4,5]:
                for ratio in [1.2,1.3,1.4,1.5,1.6]:
                    for try_no in range(10):
                        with open(f"results2/n={n}_nobins={no_bins}_no_iter={no_iterations}_ratio={ratio}_d={degree}_{try_no}.json") as f:
                            try:
                                data = json.loads(f.read())
                                m = data["measurements"]
                                try:
                                    result_binning[n][degree][m].append(data)
                                except:
                                    result_binning[n][degree][m] = [data]
                            except:
                                print(f"couldn't find results2/n={n}_nobins={no_bins}_no_iter={no_iterations}_ratio={ratio}_d={degree}_{try_no}.json")
                    
print(result_binning[4][2][3])
# Out:
# [{'status': False, 'time': 0.0027794837951660156, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.2, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0024178028106689453, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.2, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.003289461135864258, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.2, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.003291606903076172, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.2, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0010609626770019531, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.2, 'd': 2, 'measurements': 3}, {'status': True, 'time': 0.0010540485382080078, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.2, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0010929107666015625, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.2, 'd': 2, 'measurements': 3}, {'status': True, 'time': 0.0013232231140136719, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.2, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0014674663543701172, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.2, 'd': 2, 'measurements': 3}, {'status': True, 'time': 0.001470327377319336, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.2, 'd': 2, 'measurements': 3}, {'status': True, 'time': 0.001004934310913086, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.3, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0009484291076660156, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.3, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0012907981872558594, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.3, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.000732421875, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.3, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0007822513580322266, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.3, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0010497570037841797, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.3, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0009069442749023438, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.3, 'd': 2, 'measurements': 3}, {'status': True, 'time': 0.0014739036560058594, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.3, 'd': 2, 'measurements': 3}, {'status': True, 'time': 0.0014324188232421875, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.3, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0014619827270507812, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.3, 'd': 2, 'measurements': 3}, {'status': True, 'time': 0.0010242462158203125, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.4, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0010802745819091797, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.4, 'd': 2, 'measurements': 3}, {'status': True, 'time': 0.0009453296661376953, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.4, 'd': 2, 'measurements': 3}, {'status': True, 'time': 0.0013043880462646484, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.4, 'd': 2, 'measurements': 3}, {'status': True, 'time': 0.0013022422790527344, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.4, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0008947849273681641, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.4, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0008165836334228516, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.4, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0011987686157226562, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.4, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.001230478286743164, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.4, 'd': 2, 'measurements': 3}, {'status': True, 'time': 0.0014526844024658203, 'n': 4, 'no_bins': 1, 'no_iterations': 1, 'ratio': 1.4, 'd': 2, 'measurements': 3}, {'status': False, 'time': 0.0014 ...

# %%
# failure rates
for n in result_binning:
    for degree in result_binning[n]:
        no_measurements , p_failure, time  = [], [], []
        print(degree)
        for m in result_binning[n][degree]:
            l = len(result_binning[n][degree][m])
            p = sum([1 for j in range(l) if result_binning[n][degree][m][j]["status"]==True])/l
            no_measurements.append(m)
            p_failure.append(p)
            time.append(np.median([result_binning[n][degree][m][j]["time"] for j in range(l)]))
            
        # print(p_failure, time)
        fig, (ax1, ax2) = plt.subplots(2, 1)
        ax1.set_ylabel("probability of success", color="blue")
        ax1.set_xlabel("number of measurments")
        my_len = len(no_measurements)
        ax1.plot(no_measurements, p_failure, ".")
        ax1.plot([2*degree*np.log2(n)]*my_len, np.linspace(0,1,my_len), ".")
        ax1.xaxis.grid()
        ax1.yaxis.grid()
        ax1.set_title(f"n={n} degree={degree}")
        
        ax2.set_ylabel("median time (s)", color="blue")
        ax2.set_xlabel("number of measurments")
        ax2.plot(no_measurements, time, ".")
        ax2.xaxis.grid()
        ax2.yaxis.grid()
        
        
        
        plt.show()
# Out:
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5
# 2
# 3
# 4
# 5

# %%
import operator as op
from functools import reduce

def ncr(n, r):
    r = min(r, n-r)
    numer = reduce(op.mul, range(n, n-r, -1), 1)
    denom = reduce(op.mul, range(1, r+1), 1)
    return numer // denom  # or / in Python 2

def lower_bound(n,d):
    return np.log2(sum([ncr(n,i) for i in range(0,d+1)]))

# %%
print(data)
# Out:
# {'status': True, 'time': 232.21491885185242, 'n': 512, 'm': 270, 'd': 5}
